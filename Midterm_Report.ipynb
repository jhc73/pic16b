# %%
from googleapiclient.discovery import build

api_key = 'AIzaSyAJoE01-cg6OR053gcxW_Zf-FbOEvrWFvI'
youtube = build('youtube', 'v3', developerKey=api_key)

# Example: Get trending videos
request = youtube.videos().list(
    part='snippet,statistics',
    chart='mostPopular',
    regionCode='US',
    maxResults=10
)
response = request.execute()

for item in response['items']:
    print(item['snippet']['title'])
    print(item['statistics']['viewCount'])
# Out:
# Zootopia 2 | Teaser Trailer
# 4589011
# IT: Welcome to Derry | Official Teaser | HBO Max
# 1921553
# Jurassic World Rebirth | Official Trailer 2
# 2539791
# Falling In Reverse - "God Is A Weapon"
# 624846
# Schlatt's Candy Tier List
# 645901
# WAR 2 | Official Teaser | Hrithik Roshan | NTR | Kiara Advani | Ayan Mukerji | YRF Spy Universe
# 21380030
# Joey Bada$$ - MY TOWN feat. Loaded Lux (Official Audio)
# 604976
# Judge weighing throwing out Sean "Diddy" Combs trial testimony
# 2845806
# Helldivers 2 - Heart of Democracy
# 1249380
# The Bear | Season 4 Official Trailer | Jeremy Allen White, Ayo Edebiri, Ebon Moss-Bachrach | FX
# 2242983

# %%
import pandas as pd
from googleapiclient.discovery import build

api_key = 'AIzaSyAJoE01-cg6OR053gcxW_Zf-FbOEvrWFvI'
youtube = build('youtube', 'v3', developerKey=api_key)

request = youtube.videos().list(
    part='snippet,statistics',
    chart='mostPopular',
    regionCode='US',
    maxResults=20  # Try 50 if needed
)
response = request.execute()

data = []

for item in response['items']:
    title = item['snippet']['title']
    views = int(item['statistics'].get('viewCount', 0))
    published = item['snippet']['publishedAt']
    category = item['snippet'].get('categoryId', None)

    data.append({
        'title': title,
        'views': views,
        'publishedAt': published,
        'categoryId': category
    })

df = pd.DataFrame(data)
df.to_csv('youtube_trending.csv', index=False)
print("✅ Saved to youtube_trending.csv")
# Out:
# ✅ Saved to youtube_trending.csv

# %%
df = pd.read_csv('youtube_trending.csv')
print(df.head())
# Out:
#                                                title    views  \
# 0  YoungBoy Never Broke Again - Finest  [Official...  1284211
# 1  Marvel Rivals: Season 2.5 Kick Off! | Dev Visi...   457528
# 2               Wendyyy - Picasso ( Official Video )  1392956
# 3  Apex predator found dead; Is the Everglades fi...   150493
# 4  Stephen A. reacts to the Knicks' Game 1 loss 😨...   396571
#
#             publishedAt  categoryId
# 0  2025-05-21T23:48:39Z          10
# 1  2025-05-22T15:01:17Z          20
# 2  2025-05-21T19:03:34Z          10
# 3  2025-05-20T23:04:14Z          25
# 4  2025-05-22T15:22:36Z          17

# %%
import pandas as pd
from googleapiclient.discovery import build

api_key = 'AIzaSyAJoE01-cg6OR053gcxW_Zf-FbOEvrWFvI'
youtube = build('youtube', 'v3', developerKey=api_key)

region_codes = ['US', 'IN', 'GB', 'BR', 'CA', 'DE', 'FR', 'AU', 'JP', 'MX']
all_data = []

for region in region_codes:
    print(f"Fetching region: {region}")
    request = youtube.videos().list(
        part='snippet,statistics',
        chart='mostPopular',
        regionCode=region,
        maxResults=50
    )
    response = request.execute()

    for item in response['items']:
        title = item['snippet']['title']
        views = int(item['statistics'].get('viewCount', 0))
        published = item['snippet']['publishedAt']
        category = item['snippet'].get('categoryId', 'unknown')
        all_data.append({
            'region': region,
            'title': title,
            'views': views,
            'publishedAt': published,
            'categoryId': category
        })

df = pd.DataFrame(all_data)
df.to_csv('youtube_trending_all_regions.csv', index=False)
print(f"✅ Saved {len(df)} videos from {len(region_codes)} regions.")
# Out:
# Fetching region: US
# Fetching region: IN
# Fetching region: GB
# Fetching region: BR
# Fetching region: CA
# Fetching region: DE
# Fetching region: FR
# Fetching region: AU
# Fetching region: JP
# Fetching region: MX
# ✅ Saved 500 videos from 10 regions.

# %%
import pandas as pd 

pd.read_csv('youtube_trending_all_regions.csv')
# Out:
#     region                                              title    views  \
# 0       US  YoungBoy Never Broke Again - Finest  [Official...  1291316
# 1       US  Marvel Rivals: Season 2.5 Kick Off! | Dev Visi...   465329
# 2       US               Wendyyy - Picasso ( Official Video )  1395411
# 3       US  Apex predator found dead; Is the Everglades fi...   153640
# 4       US  Stephen A. reacts to the Knicks' Game 1 loss 😨...   406689
# ..     ...                                                ...      ...
# 495     MX                             El Peor Tour del Mundo   946314
# 496     MX  🟢 ENCONTRÉ el TÚNEL del RATÓN de CHUCK E CHEES...  1433443
# 497     MX  Kary Torres Oficial está en vivo Kary Pao Wend...   288059
# 498     MX  QUEDO IMPRESIONADO CON ESTA GRAN CIUDAD DE CHI...  1015070
# 499     MX                            dando vueltas por japón   549417
#
#               publishedAt  categoryId
# 0    2025-05-21T23:48:39Z          10
# 1    2025-05-22T15:01:17Z          20
# 2    2025-05-21T19:03:34Z          10
# 3    2025-05-20T23:04:14Z          25
# 4    2025-05-22T15:22:36Z          17
# ..                    ...         ...
# 495  2025-05-17T20:01:08Z          24
# 496  2025-05-17T19:10:00Z          24
# 497  2025-05-17T02:03:00Z          24
# 498  2025-05-16T01:03:40Z          22
# 499  2025-05-16T20:00:31Z          20
#
# [500 rows x 5 columns]

# %%
def classify_virality(views):
    if views > 5_000_000:
        return 'outstanding'
    elif views > 1_000_000:
        return 'medium'
    else:
        return 'meh'

df['virality_level'] = df['views'].apply(classify_virality)
